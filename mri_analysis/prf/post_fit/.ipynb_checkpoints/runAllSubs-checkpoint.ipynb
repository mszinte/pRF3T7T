# %%
mount_dir = '/home/vmorita/disks/scratch_MS/data/PredictEye'
subList = {
#     'sub-01': 'ses-03',
#     'sub-02': 'ses-02',
#     'sub-03': 'ses-02',
#     'sub-04': 'ses-02',
#     'sub-05': 'ses-02',
#     'sub-06': 'ses-02',
#     'sub-07': 'ses-02',
#     'sub-08': 'ses-02',
#     'sub-09': 'ses-02',
#     'sub-10': 'ses-02',
#     'sub-11': 'ses-02',
#     'sub-12': 'ses-02',
    'sub-13': 'ses-02',
    'sub-14': 'ses-02',
#     'sub-15': 'ses-02',
#     'sub-16': 'ses-02',
    'sub-17': 'ses-02',
#     'sub-18': 'ses-02',
#     'sub-19': 'ses-02',
    'sub-20': 'ses-02',
    'sub-21': 'ses-02',
    'sub-22': 'ses-02',
    'sub-23': 'ses-02',
    'sub-24': 'ses-02',
    'sub-25': 'ses-02',
}
tasks = ['SacLoc', 'PurLoc', 'SacVELoc', 'PurVELoc']

# %%
for sub in subList:
    for task in tasks:
        ses=subList[sub]
        print(sub,task)
        # %run 'pycortex_glm.py' $mount_dir $sub $ses $task 'T1w' 'run-01' 'fmriprep_dct' 0 1 1
# Out:
# sub-12 SacLoc
# Contrast: Task-Fix
# save pycortex flatmaps
# z_map_SacLoc_T1w_fmriprep_dct_Task-Fix
# Failed to get connection
# ** (inkscape:27054): CRITICAL **: 21:52:38.015: dbus_g_proxy_new_for_name: assertion 'connection != NULL' failed
# ** (inkscape:27054): CRITICAL **: 21:52:38.015: dbus_g_proxy_call: assertion 'DBUS_IS_G_PROXY (proxy)' failed
# ** (inkscape:27054): CRITICAL **: 21:52:38.015: dbus_g_connection_register_g_object: assertion 'connection != NULL' failed
# p_map_SacLoc_T1w_fmriprep_dct_Task-Fix
# Failed to get connection
# ** (inkscape:27135): CRITICAL **: 21:52:43.156: dbus_g_proxy_new_for_name: assertion 'connection != NULL' failed
# ** (inkscape:27135): CRITICAL **: 21:52:43.157: dbus_g_proxy_call: assertion 'DBUS_IS_G_PROXY (proxy)' failed
# ** (inkscape:27135): CRITICAL **: 21:52:43.157: dbus_g_connection_register_g_object: assertion 'connection != NULL' failed
# fdr_map_SacLoc_T1w_fmriprep_dct_Task-Fix
# Failed to get connection
# ...
